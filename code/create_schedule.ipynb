# %%
import json
from datetime import datetime

# %%
# REQUIRED DATA

# Shift ids for multiple dates
data = [
    {'shift_id': 1, 'shift_time': 'morning', 'start_time': '08:00', 'end_time': '16:00', 'date': '2024-08-12', 'weekday': 'Monday'}, 
    {'shift_id': 2, 'shift_time': 'evening', 'start_time': '16:00', 'end_time': '22:00', 'date': '2024-08-12', 'weekday': 'Monday'},

    {'shift_id': 3, 'shift_time': 'morning', 'start_time': '08:00', 'end_time': '16:00', 'date': '2024-08-13', 'weekday': 'Tuesday'},
    {'shift_id': 4, 'shift_time': 'evening', 'start_time': '16:00', 'end_time': '22:00', 'date': '2024-08-13', 'weekday': 'Tuesday'},

    {'shift_id': 5, 'shift_time': 'morning', 'start_time': '08:00', 'end_time': '16:00', 'date': '2024-08-14', 'weekday': 'Wednesday'},
    {'shift_id': 6, 'shift_time': 'evening', 'start_time': '16:00', 'end_time': '22:00', 'date': '2024-08-14', 'weekday': 'Wednesday'},

    {'shift_id': 7, 'shift_time': 'morning', 'start_time': '08:00', 'end_time': '16:00', 'date': '2024-08-15', 'weekday': 'Thursday'},
    {'shift_id': 8, 'shift_time': 'evening', 'start_time': '16:00', 'end_time': '22:00', 'date': '2024-08-15', 'weekday': 'Thursday'},

    {'shift_id': 9, 'shift_time': 'morning', 'start_time': '08:00', 'end_time': '16:00', 'date': '2024-08-16', 'weekday': 'Friday'},
    {'shift_id': 10, 'shift_time': 'evening', 'start_time': '16:00', 'end_time': '22:00', 'date': '2024-08-16', 'weekday': 'Friday'},

    {'shift_id': 11, 'shift_time': 'morning', 'start_time': '08:00', 'end_time': '16:00', 'date': '2024-08-17', 'weekday': 'Saturday'},
    {'shift_id': 12, 'shift_time': 'evening', 'start_time': '16:00', 'end_time': '22:00', 'date': '2024-08-17', 'weekday': 'Saturday'},

    {'shift_id': 13, 'shift_time': 'morning', 'start_time': '08:00', 'end_time': '16:00', 'date': '2024-08-18', 'weekday': 'Sunday'},
    {'shift_id': 14, 'shift_time': 'evening', 'start_time': '16:00', 'end_time': '22:00', 'date': '2024-08-18', 'weekday': 'Sunday'}
]



# Employee roles and weekly hours
employees = [
    {"employee_id": "Alessandro", "contracted_hours": 40, "role_id": "cashier"},
    {"employee_id": "Alessia", "contracted_hours": 40, "role_id": "cashier"},
    {"employee_id": "William", "contracted_hours": 40, "role_id": "waiter"},
    {"employee_id": "Saurabh", "contracted_hours": 40, "role_id": "waiter"},
    {"employee_id": "Benjamin", "contracted_hours": 40, "role_id": "cook"},
    {"employee_id": "Beatrice", "contracted_hours": 40, "role_id": "cook"},
    {"employee_id": "Sara", "contracted_hours": 40, "role_id": "waitress"},
    {"employee_id": "Maria", "contracted_hours": 40, "role_id": "waitress"},
]

# Sample constraints with availability for different dates


availability = {
    "Alessandro": {
        "2024-08-12": {"morning": True, "evening": True},
        "2024-08-13": {"morning": True, "evening": True},
        "2024-08-14": {"morning": True, "evening": True},
        "2024-08-15": {"morning": True, "evening": True},
        "2024-08-16": {"morning": True, "evening": True},
        "2024-08-17": {"morning": True, "evening": True},
        "2024-08-18": {"morning": True, "evening": True},
    },

    "Alessia": {
        "2024-08-12": {"morning": True, "evening": True},
        "2024-08-13": {"morning": True, "evening": True},
        "2024-08-14": {"morning": True, "evening": True},
        "2024-08-15": {"morning": True, "evening": True},
        "2024-08-16": {"morning": True, "evening": True},
        "2024-08-17": {"morning": True, "evening": True},
        "2024-08-18": {"morning": True, "evening": True},
    },

    "William": {
        "2024-08-12": {"morning": True, "evening": True},
        "2024-08-13": {"morning": True, "evening": True},
        "2024-08-14": {"morning": True, "evening": True},
        "2024-08-15": {"morning": True, "evening": True},
        "2024-08-16": {"morning": True, "evening": True},
        "2024-08-17": {"morning": True, "evening": True},
        "2024-08-18": {"morning": True, "evening": True},
    },

    "Saurabh": {
        "2024-08-12": {"morning": True, "evening": True},
        "2024-08-13": {"morning": True, "evening": True},
        "2024-08-14": {"morning": True, "evening": True},
        "2024-08-15": {"morning": True, "evening": True},
        "2024-08-16": {"morning": True, "evening": True},
        "2024-08-17": {"morning": True, "evening": True},
        "2024-08-18": {"morning": True, "evening": True},
    },

     "Benjamin": {
        "2024-08-12": {"morning": True, "evening": True},
        "2024-08-13": {"morning": True, "evening": True},
        "2024-08-14": {"morning": True, "evening": True},
        "2024-08-15": {"morning": True, "evening": True},
        "2024-08-16": {"morning": True, "evening": True},
        "2024-08-17": {"morning": True, "evening": True},
        "2024-08-18": {"morning": True, "evening": True},
    },


    "Beatrice": {
        "2024-08-12": {"morning": True, "evening": True},
        "2024-08-13": {"morning": True, "evening": True},
        "2024-08-14": {"morning": True, "evening": True},
        "2024-08-15": {"morning": True, "evening": True},
        "2024-08-16": {"morning": True, "evening": True},
        "2024-08-17": {"morning": True, "evening": True},
        "2024-08-18": {"morning": True, "evening": True},
    },


     "Sara": {
        "2024-08-12": {"morning": True, "evening": True},
        "2024-08-13": {"morning": True, "evening": True},
        "2024-08-14": {"morning": True, "evening": True},
        "2024-08-15": {"morning": True, "evening": True},
        "2024-08-16": {"morning": True, "evening": True},
        "2024-08-17": {"morning": True, "evening": True},
        "2024-08-18": {"morning": True, "evening": True},
    },

    
     "Maria": {
        "2024-08-12": {"morning": True, "evening": True},
        "2024-08-13": {"morning": True, "evening": True},
        "2024-08-14": {"morning": True, "evening": True},
        "2024-08-15": {"morning": True, "evening": True},
        "2024-08-16": {"morning": True, "evening": True},
        "2024-08-17": {"morning": True, "evening": True},
        "2024-08-18": {"morning": True, "evening": True},
    },
}



roles_schedule_by_shift = {
    "Mon": {
        "morning": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
        "evening": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
    },
    "Tue": {
        "morning": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
        "evening": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
    },
    "Wed": {
        "morning": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
        "evening": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
    },
    "Thu": {
        "morning": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
        "evening": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
    },
    "Fri": {
        "morning": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
        "evening": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
    },
    "Sat": {
        "morning": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
        "evening": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
    },
    "Sun": {
        "morning": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
        "evening": {
            "cashier": 1,
            "waiter": 1,
            "cook": 1,
            "waitress": 1
        },
    }
}

# %%
# SCHEDULER

def assign_roles_by_shift(shifts, roles_schedule_by_shift, employees, availability):
    schedule_by_shift_id = {}
    
    # Create a dictionary to keep track of assigned hours for each employee
    employee_assigned_hours = {emp['employee_id']: 0 for emp in employees}
    
    # Create a dictionary to track how many shifts an employee is assigned per day
    employee_daily_shifts = {emp['employee_id']: {} for emp in employees}

    for shift in shifts:
        shift_id = shift['shift_id']
        shift_time = shift['shift_time']  # Morning or Evening
        shift_date = shift['date']
        weekday = shift['weekday'][:3]  # Get first 3 letters of weekday

        if weekday not in roles_schedule_by_shift:
            continue

        if shift_id not in schedule_by_shift_id:
            schedule_by_shift_id[shift_id] = {
                "roles": {}
            }

        roles_required = roles_schedule_by_shift[weekday].get(shift_time, {})

        shift_start = shift['start_time']
        shift_end = shift['end_time']
        shift_duration = (datetime.strptime(shift_end, "%H:%M") - datetime.strptime(shift_start, "%H:%M")).seconds // 3600

        for role, employees_required in roles_required.items():
            if role not in schedule_by_shift_id[shift_id]["roles"]:
                schedule_by_shift_id[shift_id]["roles"][role] = []

            # Filter employees by role
            eligible_employees = [emp for emp in employees if emp['role_id'] == role]
            
            # Sort employees by remaining contracted hours (descending)
            eligible_employees.sort(key=lambda x: x['contracted_hours'] - employee_assigned_hours[x['employee_id']], reverse=True)

            for _ in range(employees_required):
                for employee in eligible_employees:
                    emp_id = employee['employee_id']

                    # Initialize the shift count for the employee on this date if not already initialized
                    if shift_date not in employee_daily_shifts[emp_id]:
                        employee_daily_shifts[emp_id][shift_date] = 0

                    if (
                        availability.get(emp_id, {}).get(shift_date, {}).get(shift_time, False) and
                        employee['contracted_hours'] - employee_assigned_hours[emp_id] >= shift_duration and
                        employee_daily_shifts[emp_id][shift_date] < 1 and
                        emp_id not in schedule_by_shift_id[shift_id]["roles"][role]
                    ):
                        # Assign the employee to the role in this shift
                        schedule_by_shift_id[shift_id]["roles"][role].append(emp_id)
                        employee_assigned_hours[emp_id] += shift_duration
                        employee_daily_shifts[emp_id][shift_date] += 1
                        break
                else:
                    # If no eligible employee found, leave this slot empty
                    schedule_by_shift_id[shift_id]["roles"][role].append(None)

    # Convert to JSON structure
    schedule_json = json.dumps(schedule_by_shift_id, indent=4)
    
    return schedule_json

# Create the schedule
schedule_json = assign_roles_by_shift(data, roles_schedule_by_shift, employees, availability)

# Display the JSON structured schedule
print(schedule_json)
# Out:
# {
#     "1": {
#         "roles": {
#             "cashier": [
#                 "Alessia"
#             ],
#             "waiter": [
#                 "William"
#             ],
#             "cook": [
#                 "Benjamin"
#             ],
#             "waitress": [
#                 "Sara"
#             ]
#         }
#     },
#     "2": {
#         "roles": {
#             "cashier": [
#                 "Alessandro"
#             ],
#             "waiter": [
#                 "Saurabh"
#             ],
#             "cook": [
#                 "Beatrice"
#             ],
#             "waitress": [
#                 "Maria"
#             ]
#         }
#     },
#     "3": {
#         "roles": {
#             "cashier": [
#                 "Alessandro"
#             ],
#             "waiter": [
#                 "Saurabh"
#             ],
#             "cook": [
#                 "Beatrice"
#             ],
#             "waitress": [
#                 "Maria"
# ...
